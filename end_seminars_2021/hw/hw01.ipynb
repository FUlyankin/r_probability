# %% [markdown]
# <img src="https://raw.githubusercontent.com/FUlyankin/r_probability/master/end_seminars/sem_2/yYGiBqtirSM.jpg" height="300" width="300">
#
# # <center> R для тервера и матстата. <br>  <br> Домашка номер раз! </center>

# %% [markdown]
# __Брифинг:__
#
# 1. Be good, drink milk and [think of Russia.](https://www.youtube.com/watch?v=jyxSFfBKMxQ) (c)
# 2. Обязательно фиксируйте зерно генератора случайных чисел в экспериментах. При перезапуске кода значения не должны меняться :)
# 3. Залейте тетрадку с решением на Google Colab. Нажмите кнопку share. Разрешите по ней редактировать тетрадку. Залейте ссылку в форму для сдачи домашек.
# 4. Дедлайн:
# 5. [На страничке курса](https://github.com/FUlyankin/r_probability) есть решение домашек прошлого года. Ими можно пользоваться.

# %%
library("ggplot2")  # Пакет для красивых графиков 
library("reshape2")

library("grid")     # Пакет для субплотов

# Отрегулируем размер картинок, которые будут выдаваться в нашей тетрадке
library('repr')
options(repr.plot.width=4, repr.plot.height=3)

# %% [markdown]
# ## [10] Задачка 1: Круиз
#
# Пассажир круизного лайнера "ВечноЗелёный" заразился новым вирусом. Симптомы у носителя такого вируса проявляются только на $14$ день после заражения. Больной с симптомами сразу же отправляется в специальную каюту на самоизоляцию. Количество людей, которое в течение дня может заразить один носитель вируса, имеет биномиальное распределение с параметрами $n=10$ и $p=0.02$. На лайнере плывёт 400 человек. На какой день плавания наиболее вероятно, что все люди на корабле окажутся в специальной каюте на самоизоляции?

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆ ваш код

# %% [markdown]
# ## [20] Задачка 2: Парадокс инспектора
#
# __Пояснения:__ первый автобус можно не включать в выборку, Пумбу за пассажира можно не считать.
#
# Автобусы отходят от автостанции с 8:00 до 20:00. Первый автобус отходит ровно в 8:00. Затем интервалы между автобусами случайны, независимы и равновероятно равны либо 5-и, либо 10-и минутам. Будем считать, что за минуту на автостанцию приходит ровно один пассажир, и все пассажиры едут ближайшим автобусом.
#
# Проведите $10^4$ экспериментов и с их помощью:
#
# __а)__ Постройте гистограмму количества автобусов, отошедших от автостанции за сутки. Похоже ли визуально распределение на нормальное?

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆ Я изгоняю тебя Саруман, как яд изгоняют из раны.

# %% [markdown]
# __б)__ Инспектор Тимон выбирает равновероятно один из всех автобусов отошедших от автостанции за сутки. Постройте гистограмму числа пассажиров на этом автобусе. Оцените математическое ожидание и дисперсию этого числа.

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆ Ждите меня с первым лучом солнца, я приду на 5-ый день, с востока.

# %% [markdown]
# __в)__ Инспектор Пумба приходит на автостанцию в случайный момент времени, равномерный от 8:00 до 20:00 и садится в первый пришедший автобус. Постройте гистограмму числа пассажиров на этом автобусе. Оцените математическое ожидание и дисперсию этого числа.

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆ Не жалей умерших, Гарри. Жалей живых, и в особенности тех, кто живет без любви.

# %% [markdown]
# __г)__ Как изменятся ответы на эти вопросы, если время между автобусами будет экспоненциально со средним в 10 минут?

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆  Если я в чём-то сомневаюсь, я возвращаюсь к началу.

# %% [markdown]
# __д)__ Словами проинтерпретируйте полученные в ходе симуляций результаты. В чём заключается [парадокс инспектора?](https://towardsdatascience.com/the-inspection-paradox-is-everywhere-2ef1c2e9d709)

# %% [markdown]
# __Ответ:__

# %% [markdown]
# ## [25] Задачка 3:  Парадокс Хуана Мануэля Родригеса Паррондо
#
# У Атоса, Портоса и Арамиса по 1000 франков.
#
# - Атос постоянно ходит в казино А, где каждый раз выигрывает один франк с вероятностью $0.49$ и проигрывает один франк с вероятностью $0.51$.
# - Портос ходит в казино Б, где ситуация интереснее :) Если богатство посетителя кратно трём, то посетитель выигрывает франк с вероятностью $0.09$ и проигрывает один франк с вероятностью $0.91$. Если богатство посетителя не кратно трём, то посетитель выигрывает франк с вероятностью $0.74$ и проигрывает один франк с вероятностью $0.26$.
# - Арамис каждый раз выбирает казино А или казино Б равновероятно.
#
# Проведите $10^4$ симуляций эволюции благосостояния Атоса, Портоса и Арамиса. Каждая симуляция предусматривает $1000$ посещений казино. Все три игрока все деньги носят с собой и ни на что не тратят :)
#
# __а)__ Постройте на графике $10$ случайных траекторий изменений богатства Атоса, по горизонтали — номер посещени казино, по вертикали — богатство. На том же графике постройте усреднённую по всем экспериментам тракторию изменения богатства.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  Peace is a lie, there is only passion.

# %% [markdown]
# __б)__ Постройте на графике $10$ случайных траекторий изменений богатства Портоса, по горизонтали — номер посещени казино, по вертикали — богатство.  На том же графике постройте усреднённую по всем экспериментам тракторию изменения богатства.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════   Through passion, I gain strength.

# %% [markdown]
# __в)__ Постройте на графике $10$ случайных траекторий изменений богатства Арамиса, по горизонтали — номер посещени казино, по вертикали — богатство. На том же графике постройте усреднённую по всем экспериментам тракторию изменения богатства.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════   Through strength, I gain power.

# %% [markdown]
# __г)__ Словами проинтерпретируйте полученные в ходе симуляций результаты. В чём заключается [парадокс Парондо?](https://en.wikipedia.org/wiki/Parrondo%27s_paradox) Какую роль во всех этих симуляциях сыграл ЗБЧ?

# %% [markdown]
# __Ответ:__

# %% [markdown]
# ## [20] Задачка 4:  Парадокс Берксона
#
# Предположим, что результаты ЕГЭ школьников по русскому и математике независимы и хорошо аппроксимируются
# нормальным распределением с ожиданием 60 и стандартным отклонением $10$.
#
# ВАХ (Воронежская Академия Хозяйства) ныне престижна и забирает себе всех школьников набравших более $n$ баллов в сумме по русскому и математике. Для каждого $n$ от $80$ до $160$ с шагом $5$ случайно создайте $10^4$ школьников и поделите их на прошедших и не прошедших в ВАХ.
#
# __а)__  Постройте график числа прошедших в ВАХ в зависимости от $n$.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════   Through power, I gain victory.

# %% [markdown]
# __б)__ Постройте график выборочной корреляции между результатами по русскому и математике в зависимости от $n$ среди прошедших в ВАХ.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  Through victory, my chains are broken.

# %% [markdown]
# __в)__ Постройте график выборочной корреляции между результатами по русскому и математике в зависимости от $n$ среди не прошедших в ВАХ.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  The Force shall free me.

# %% [markdown]
# __г)__ Словами проинтерпретируйте полученные в ходе симуляций результаты. В чём заключается [парадокс Берксона?](https://en.wikipedia.org/wiki/Berkson%27s_paradox)

# %% [markdown]
# __Ответ:__

# %% [markdown]
# ## [5] Задачка 5:  И это всё?!
#
# Сгенерируйте выборку для случайной величины, которая обладает следующей функцией распределения:
#
#
# $$
# F(x) = \begin{cases} 0, x \le 0 \\ \sin(x), x \in (0, \pi/2] \\ 1, x>\pi/2 \end{cases}
# $$
#
# Нарисуйте для неё гистограмму, эмпирическую функцию распределения. Оцените математическое ожидание, дисперсию, медиану. Найдите её $5\%$ и $95\%$ квантили.

# %%
### ╰( ͡° ͜ʖ ͡° )つ▬▬ι═══════  bzzzzzz

# %% [markdown]
# Как думаете для моделирования каких явлений эта случайная величина могла бы оказаться полезной?
#
# __Ответ:__

# %% [markdown]
# ## [10] Задачка 6:  тоска по Палычу
#
# Вера сидит на самоизоляции. У неё есть куча книг и интернет, но она всё-равно скучает. Скучает по Василию Павловичу Решетникову и его лекциям по матстату. Ей безумно не хватает его экспрессии и таланта рассказчика. Сегодня тоска окончательно разъела сердце Веры. Поэтому она стала генеировровать равномерные случайные величины.

# %% [markdown]
# __а)__ Ксюша взяла независимые случайные величны $X, Y \sim U[1,2]$. Немного поколдовав, она получила случайную величину $Z = \frac{X}{X + Y}$.
#
# Давайте нарисуем для этой случайной величины ЗБЧ. С помощью симуляций оцените математическое ожидание этой случайной величины сначала на $10$, потом на $11$, $\ldots$ , потом на $1000$ наблюдениях. Нарисуйте картинку, на которой будет видно к чему сходится среднее.

# %%
    # ┬─┬ ノ( ゜-゜ノ)       Писать код самому? 
    
    # (╯° □°)╯︵ ┻━┻

# %% [markdown]
# Зафиксируйте несколько коридоров по аналогии с тем, что мы делали на паре. Пронаблюдайте за тем, как ведут себя вероятности пробить эти коридоры при увеличении $n$.

# %%
    # ┬─┬ ノ( ゜-゜ノ)       Писать код самому? 
    
    # (╯° □°)╯︵ ┻━┻

# %% [markdown]
# __б)__ Тепреь Вера взяла независимые случайные величны $X, Y \sim U[-1,1]$. Постройте для выборочного среднего, расчитанного для $Z = \frac{X}{X + Y}$ две аналогичные картинки.

# %%
    # ┬─┬ ノ( ゜-゜ノ)       Писать код самому? 
    
    # (╯° □°)╯︵ ┻━┻

# %% [markdown]
# __в)__ Проинтерпретируйте то, что вы увидели выше. Как думаете, почему с этой случайной величиной происходит такая странность?

# %% [markdown]
# __Ответ:__

# %% [markdown]
# ## [10] Задачка 7:  сходимости

# %% [markdown]
# __Эта задача решается без симуляций. Либо решите её на бумаге и вставьте в тетрадку фотку, либо вбивайте все формулы в техе.__
#
# Определите как (по распределению, по вероятности, в среднем) и к чему сходятся следущие последовательности случайных величин:
#
# * $X_n \sim U\left[0 ; \frac{1}{n} \right]$
# * $X_n \sim N\left(0, \frac{1}{n}\right)$
# * $X_n \sim Exp(n)$
# * $X_n \sim Exp\left(\frac{1}{n} \right)$
# * $X_n \sim Bern\left(\frac{1}{n}\right)$
# * $X_n \sim N\left(\frac{n-1}{n+1}, 9\right)$
# * $X_n \sim N\left(0, \frac{5 + n}{n^2}\right)$
# * $X_n \sim N \left(\frac{n-8}{n^2 + 8}, \frac{n+1}{n-1} \right)$
# * $X_n \sim t(n)$
# * $X_n = \frac{Y_n}{n}$, где $Y_n \sim \chi^2_n$
# * $X_n = \frac{Y_n}{n+5}$, где $Y_n \sim \chi^2_n$
# * $X_n = 2011 \cdot  Y_n$, где $Y_n \sim F_{2011,n}$
# * $X_n = \frac{Y_n - n}{\sqrt{n}}$, где $Y_n \sim \chi^2_n$
#
# Обоснование сходимости должно быть дано максимально чётко.
